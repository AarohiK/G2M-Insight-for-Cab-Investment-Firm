# %% [markdown]
# # G2M insight for Cab Investment Firm

# %% [markdown]
# ### Step 1: Importing Necessary Libraries

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['agg.path.chunksize'] = 10000
import seaborn as sns
sns.set()
import xlrd

# %% [markdown]
# ### Step 2: Merge all datasets into one csv file

# %% [markdown]
# ### Read the final csv file

# %%
dataf = pd.read_csv("./Master_Cab_Data.csv")
city_d = pd.read_csv("./City.csv")
cab_d = pd.read_csv("./Cab_Data.csv")
customer_d = pd.read_csv("./Customer_ID.csv")
transaction_d = pd.read_csv("./Transaction_ID.csv")

dataf.head()
# Out:
# C:\Users\aaroh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1,2,3,6,8,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0      10000011.0     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1      10000012.0     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2      10000013.0     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3      10000014.0     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4      10000015.0     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged Cost of Trip  Customer ID Gender   Age Income (USD/Month)  \
# 0         370.95      $313.64        29290   Male  28.0         $10,813.00
# 1         358.52      $334.85        27703   Male  27.0          $9,237.00
# 2         125.20       $97.63        28712   Male  53.0         $11,242.00
# 3         377.40      $351.60        28020   Male  23.0         $23,327.00
# 4         114.62       $97.78        27182   Male  33.0          $8,536.00
#
#   Payment_Mode
# 0         Card
# 1         Card
# 2         Cash
# 3         Cash
# 4         Card

# %% [markdown]
# ### Exploring the Dataset

# %%
dataf.shape
# Out:
# (848681, 12)

# %%
dataf.columns
# Out:
# Index(['Transaction ID', 'Date of Travel', 'Company', 'City', 'KM Travelled',
#        'Price Charged', 'Cost of Trip', 'Customer ID', 'Gender', 'Age',
#        'Income (USD/Month)', 'Payment_Mode'],
#       dtype='object')

# %%
dataf.dtypes
# Out:
# Transaction ID        float64
# Date of Travel         object
# Company                object
# City                   object
# KM Travelled          float64
# Price Charged         float64
# Cost of Trip           object
# Customer ID             int64
# Gender                 object
# Age                   float64
# Income (USD/Month)     object
# Payment_Mode           object
# dtype: object

# %%
dataf.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0      10000011.0     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1      10000012.0     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2      10000013.0     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3      10000014.0     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4      10000015.0     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged Cost of Trip  Customer ID Gender   Age Income (USD/Month)  \
# 0         370.95      $313.64        29290   Male  28.0         $10,813.00
# 1         358.52      $334.85        27703   Male  27.0          $9,237.00
# 2         125.20       $97.63        28712   Male  53.0         $11,242.00
# 3         377.40      $351.60        28020   Male  23.0         $23,327.00
# 4         114.62       $97.78        27182   Male  33.0          $8,536.00
#
#   Payment_Mode
# 0         Card
# 1         Card
# 2         Cash
# 3         Cash
# 4         Card

# %% [markdown]
# #### Independent Variables
# - Transaction ID, a unique identifier for each trip
# - Date of Travel
# - Company, Which company (Pink Cab or Yellow Cab)
# - City
# - KM Travelled, Kilometers customer travelled
# - Price Charged, Price charged from customer
# - Cost of Trip, Cost to use cab on trip
# - Customer ID, a unique indentifier for each customer
# - Gender
# - Age
# - Income, (USD/Month)
# - Payment_Mode

# %% [markdown]
# ### Unique Values of all Columns

# %%
dataf.nunique()
# Out:
# Transaction ID        440098
# Date of Travel          1095
# Company                    2
# City                      20
# KM Travelled             874
# Price Charged          99176
# Cost of Trip           14760
# Customer ID            49171
# Gender                     2
# Age                       48
# Income (USD/Month)     46682
# Payment_Mode               2
# dtype: int64

# %%
dataf.describe()
# Out:
#        Transaction ID   KM Travelled  Price Charged    Customer ID  \
# count    7.994900e+05  359392.000000  359392.000000  848681.000000
# mean     1.022037e+07      22.567254     423.443311   23550.055591
# std      1.269382e+05      12.233526     274.378911   21182.604797
# min      1.000001e+07       1.900000      15.600000       1.000000
# 25%      1.011042e+07      12.000000     206.437500    3500.000000
# 50%      1.022055e+07      22.440000     386.360000   14866.000000
# 75%      1.033037e+07      32.960000     583.660000   43867.000000
# max      1.044011e+07      48.000000    2048.030000   60000.000000
#
#                 Age
# count  98342.000000
# mean      35.363121
# std       12.599002
# min       18.000000
# 25%       25.000000
# 50%       33.000000
# 75%       42.000000
# max       65.000000

# %% [markdown]
# #### Insights:
# - Average KM Travelled is 22.567 kilometers
# - Average age is 35
# - Min age is 18

# %%
dataf.head(10)
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0      10000011.0     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1      10000012.0     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2      10000013.0     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3      10000014.0     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4      10000015.0     2016-01-03  Pink Cab  ATLANTA GA          8.73
# 5      10000016.0     2016-01-07  Pink Cab  ATLANTA GA          6.06
# 6      10000017.0     2016-01-03  Pink Cab   AUSTIN TX         44.00
# 7      10000018.0     2016-01-07  Pink Cab   AUSTIN TX         35.65
# 8      10000019.0     2016-01-12  Pink Cab   BOSTON MA         14.40
# 9      10000020.0     2016-01-06  Pink Cab   BOSTON MA         10.89
#
#    Price Charged Cost of Trip  Customer ID Gender   Age Income (USD/Month)  \
# 0         370.95      $313.64        29290   Male  28.0         $10,813.00
# 1         358.52      $334.85        27703   Male  27.0          $9,237.00
# 2         125.20       $97.63        28712   Male  53.0         $11,242.00
# 3         377.40      $351.60        28020   Male  23.0         $23,327.00
# 4         114.62       $97.78        27182   Male  33.0          $8,536.00
# 5          72.43       $63.02        27318   Male  25.0         $13,984.00
# 6         576.15      $475.20        33788   Male  23.0         $23,788.00
# 7         466.10      $377.89        34106   Male  19.0         $19,980.00
# 8         191.61      $146.88        59799   Male  33.0         $19,271.00
# 9         156.98      $113.26        57982   Male  57.0          $5,068.00
#
#   Payment_Mode
# 0         Card
# 1         Card
# 2         Cash
# 3         Cash
# 4         Card
# 5         Cash
# 6         Card
# 7         Card
# 8         Cash
# 9         Cash

# %% [markdown]
# ### CITY DATASET

# %%
print(city_d.shape)
# Out:
# (20, 3)

# %%
city_d.head(10)
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247
# 5   ORANGE COUNTY   1,030,185     12,994
# 6    SAN DIEGO CA     959,307     69,995
# 7      PHOENIX AZ     943,999      6,133
# 8       DALLAS TX     942,908     22,157
# 9      ATLANTA GA     814,885     24,701

# %%
city_d.dtypes
# Out:
# City          object
# Population    object
# Users         object
# dtype: object

# %%
city_d['Population'] = [x.replace(',','') for x in city_d['Population']]
city_d['Users'] = [x.replace(',','') for x in city_d['Users']]
city_d['Population'] = city_d['Population'].astype(float)
city_d['Users'] = city_d['Users'].astype(float)

# %%
city_d.dtypes
# Out:
# City           object
# Population    float64
# Users         float64
# dtype: object

# %% [markdown]
# ### TRANSACTION_ID DATASET

# %%
print(transaction_d.shape)
# Out:
# (440098, 3)

# %%
transaction_d.head(10)
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card
# 5        10000016        27318         Cash
# 6        10000017        33788         Card
# 7        10000018        34106         Card
# 8        10000019        59799         Cash
# 9        10000020        57982         Cash

# %%
transaction_d.dtypes
# Out:
# Transaction ID     int64
# Customer ID        int64
# Payment_Mode      object
# dtype: object

# %% [markdown]
# ### Customer_ID DATASET

# %%
print(customer_d.shape)
# Out:
# (49171, 4)

# %%
customer_d.head(10)
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536
# 5        27318   Male   25               13984
# 6        33788   Male   23               23788
# 7        34106   Male   19               19980
# 8        59799   Male   33               19271
# 9        57982   Male   57                5068

# %%
customer_d.dtypes
# Out:
# Customer ID            int64
# Gender                object
# Age                    int64
# Income (USD/Month)     int64
# dtype: object

# %%
dataf.head()
# Out:
#    Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0      10000011.0     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1      10000012.0     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2      10000013.0     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3      10000014.0     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4      10000015.0     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged Cost of Trip  Customer ID Gender   Age Income (USD/Month)  \
# 0         370.95      $313.64        29290   Male  28.0         $10,813.00
# 1         358.52      $334.85        27703   Male  27.0          $9,237.00
# 2         125.20       $97.63        28712   Male  53.0         $11,242.00
# 3         377.40      $351.60        28020   Male  23.0         $23,327.00
# 4         114.62       $97.78        27182   Male  33.0          $8,536.00
#
#   Payment_Mode
# 0         Card
# 1         Card
# 2         Cash
# 3         Cash
# 4         Card

# %%
dataf.dtypes
# Out:
# Transaction ID        float64
# Date of Travel         object
# Company                object
# City                   object
# KM Travelled          float64
# Price Charged         float64
# Cost of Trip           object
# Customer ID             int64
# Gender                 object
# Age                   float64
# Income (USD/Month)     object
# Payment_Mode           object
# dtype: object

# %%
final_data = cab_d.merge(transaction_d, on= 'Transaction ID').merge(customer_d, on ='Customer ID').merge(city_d, on = 'City')

# %%
final_data.head(10)
# Out:
#    Transaction ID  Date of Travel     Company        City  KM Travelled  \
# 0        10000011           42377    Pink Cab  ATLANTA GA         30.45
# 1        10351127           43302  Yellow Cab  ATLANTA GA         26.19
# 2        10412921           43427  Yellow Cab  ATLANTA GA         42.55
# 3        10000012           42375    Pink Cab  ATLANTA GA         28.62
# 4        10320494           43211  Yellow Cab  ATLANTA GA         36.38
# 5        10324737           43224  Yellow Cab  ATLANTA GA          6.18
# 6        10395626           43400    Pink Cab  ATLANTA GA         13.39
# 7        10000013           42371    Pink Cab  ATLANTA GA          9.04
# 8        10079404           42634  Yellow Cab  ATLANTA GA         39.60
# 9        10186994           42909  Yellow Cab  ATLANTA GA         18.19
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode Gender  Age  \
# 0         370.95      313.6350        29290         Card   Male   28
# 1         598.70      317.4228        29290         Cash   Male   28
# 2         792.05      597.4020        29290         Card   Male   28
# 3         358.52      334.8540        27703         Card   Male   27
# 4         721.10      467.1192        27703         Card   Male   27
# 5         138.40       87.5088        27703         Cash   Male   27
# 6         167.03      141.9340        27703         Card   Male   27
# 7         125.20       97.6320        28712         Cash   Male   53
# 8         704.30      494.2080        28712         Card   Male   53
# 9         365.63      246.6564        28712         Card   Male   53
#
#    Income (USD/Month)  Population    Users
# 0               10813    814885.0  24701.0
# 1               10813    814885.0  24701.0
# 2               10813    814885.0  24701.0
# 3                9237    814885.0  24701.0
# 4                9237    814885.0  24701.0
# 5                9237    814885.0  24701.0
# 6                9237    814885.0  24701.0
# 7               11242    814885.0  24701.0
# 8               11242    814885.0  24701.0
# 9               11242    814885.0  24701.0

# %%
from datetime import datetime, timedelta

# %%
def date_f(x):
    date_str =(datetime(1899,12,30) + timedelta(x-1)).strftime("%d-%m-%Y")
    date_r =  datetime.strptime(date_str, "%d-%m-%Y")
    return date_r

# %%
final_data['Date of Travel']=final_data['Date of Travel'].apply(lambda x:date_f(x))

# %% [markdown]
# ### Features Analysis

# %% [markdown]
# #### Plot 1: Km Travelled vs Price Charged

# %%
plt.figure(figsize=(17,9))
sns.lineplot(data=final_data, x="KM Travelled",y='Cost of Trip')
plt.title('Cost of Trip vs KM Travelled', fontsize=20)
plt.xlabel('Travelled')
plt.ylabel('Cost')
plt.show()

# %% [markdown]
# #### we can see there's a postive trend as the more kilometers travelled equals to more cost for the trip.

# %% [markdown]
# ### Plot 2: KM travelled distribution

# %%
plt.figure(figsize=(17,9))
plot2=sns.histplot(data=final_data, x="KM Travelled",bins=40, color= 'Black')
plt.title('Km Travelled Distribution', fontsize=20)
plt.ylabel('Frequency')
plt.xlabel('Km Travelled')
# Out:
# Text(0.5, 0, 'Km Travelled')

# %% [markdown]
# #### Majority of customers travelled close to 12000 kilometers

# %% [markdown]
# ### Plot 3: Price Charged Distribution

# %%
plt.figure(figsize=(17,9))
plot2=sns.histplot(data=final_data, x="Price Charged",bins=40, color= 'pink')
plt.title('Price Charged Distribution', fontsize=20)
plt.ylabel('Frequency')
plt.xlabel('Price Charged')
# Out:
# Text(0.5, 0, 'Price Charged')

# %% [markdown]
# #### Majority were charged from 100 - 450 Dollars

# %% [markdown]
# ### Plot 4:  Customer Age Distributions

# %%
plt.figure(figsize=(17,9))
plot2=sns.histplot(data=final_data, x="Age",bins=40, color= 'red')
plt.title('Customer Age Distribution', fontsize=20)
plt.ylabel('Frequency')
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# #### Majority of customers are between 20-40

# %% [markdown]
# ### Plot 5: Payment Methods

# %%
plt.figure(figsize=(17,9))
plot2=sns.histplot(data=final_data, x="Payment_Mode", color = "olive")
plt.title('Customer Payment Method', fontsize=20)
plt.ylabel('Frequency')
plt.xlabel('Payment Method')
# Out:
# Text(0.5, 0, 'Payment Method')

# %% [markdown]
# #### Most customer's payment method is by using a card.

# %% [markdown]
# ### Plot 6: Users per City

# %%
plt.figure(figsize=(20, 17));
pl6=sns.barplot(x="Users", y="City", data=city_d);

# %% [markdown]
# #### Majority of users are based in New York City as their population is quite high.

# %% [markdown]
# ### Plot 7: Income Distribution

# %%
plt.figure(figsize=(23,20))
sns.displot(final_data['Income (USD/Month)'], bins = 16)
plt.show()

# %% [markdown]
# #### Most users have an income from 5000 - 25000 USD/month

# %%
final_data.dtypes
# Out:
# Transaction ID                 int64
# Date of Travel        datetime64[ns]
# Company                       object
# City                          object
# KM Travelled                 float64
# Price Charged                float64
# Cost of Trip                 float64
# Customer ID                    int64
# Payment_Mode                  object
# Gender                        object
# Age                            int64
# Income (USD/Month)             int64
# Population                   float64
# Users                        float64
# dtype: object

# %%
final_data['Income (USD/Month)'] = final_data['Income (USD/Month)'].astype(float)
final_data.dtypes
# Out:
# Transaction ID                 int64
# Date of Travel        datetime64[ns]
# Company                       object
# City                          object
# KM Travelled                 float64
# Price Charged                float64
# Cost of Trip                 float64
# Customer ID                    int64
# Payment_Mode                  object
# Gender                        object
# Age                            int64
# Income (USD/Month)           float64
# Population                   float64
# Users                        float64
# dtype: object

# %%
final_data.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# Transaction ID        0
# Date of Travel        0
# Company               0
# City                  0
# KM Travelled          0
# Price Charged         0
# Cost of Trip          0
# Customer ID           0
# Payment_Mode          0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# Population            0
# Users                 0
# dtype: int64

# %% [markdown]
# ####  No missing values.

# %% [markdown]
# ### Additional Columns

# %%
final_data['Profit'] = final_data['Price Charged'] - final_data['Cost of Trip']
final_data.sort_values('Date of Travel').head(7)
# Out:
#         Transaction ID Date of Travel     Company            City  \
# 12812         10000429     2016-01-01  Yellow Cab       BOSTON MA
# 43828         10000525     2016-01-01  Yellow Cab      CHICAGO IL
# 297325        10001234     2016-01-01  Yellow Cab      SEATTLE WA
# 316639        10001311     2016-01-01  Yellow Cab   WASHINGTON DC
# 171893        10000927     2016-01-01  Yellow Cab     NEW YORK NY
# 111181        10000721     2016-01-01  Yellow Cab  LOS ANGELES CA
# 316506        10001303     2016-01-01  Yellow Cab   WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode  \
# 12812          15.15         342.62      205.4340        57474         Card
# 43828           2.18          51.47       26.4216         4551         Cash
# 297325         39.60        1119.67      541.7280        38146         Cash
# 316639         34.65         707.94      474.0120        53048         Card
# 171893         34.56        1121.11      485.2224         1808         Cash
# 111181         19.20         529.23      246.5280         8117         Cash
# 316506         41.07         855.57      522.4104        51417         Cash
#
#        Gender  Age  Income (USD/Month)  Population     Users    Profit
# 12812    Male   34             16558.0    248968.0   80021.0  137.1860
# 43828    Male   19              6316.0   1955130.0  164468.0   25.0484
# 297325   Male   36              6577.0    671238.0   25063.0  577.9420
# 316639   Male   23             31566.0    418859.0  127001.0  233.9280
# 171893   Male   59             18999.0   8405837.0  302149.0  635.8876
# 111181   Male   21              5946.0   1595037.0  144132.0  282.7020
# 316506   Male   30              4042.0    418859.0  127001.0  333.1596

# %%
from datetime import datetime, timedelta
def date_f(n):
    date_str =(datetime(1899,12,30) + timedelta(n-1)).strftime("%d-%m-%Y")
    datee =  datetime.strptime(date_str, "%d-%m-%Y")
    return datee

# %%
final_data['Date of Travel'] = final_data['Date of Travel'].apply(lambda x:date_f(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1048/2257002237.py in <module>
# ----> 1 final_data['Date of Travel'] = final_data['Date of Travel'].apply(lambda x:date_f(x))
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# -> 1098                 mapped = lib.map_infer(
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\AppData\Local\Temp/ipykernel_1048/2257002237.py in <lambda>(x)
# ----> 1 final_data['Date of Travel'] = final_data['Date of Travel'].apply(lambda x:date_f(x))
#
# ~\AppData\Local\Temp/ipykernel_1048/3901583875.py in date_f(n)
#       1 from datetime import datetime, timedelta
#       2 def date_f(n):
# ----> 3     date_str =(datetime(1899,12,30) + timedelta(n-1)).strftime("%d-%m-%Y")
#       4     datee =  datetime.strptime(date_str, "%d-%m-%Y")
#       5     return datee
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__sub__()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\timestamps.pyx in pandas._libs.tslibs.timestamps._Timestamp.__add__()
#
# TypeError: Addition/subtraction of integers and integer-arrays with Timestamp is no longer supported.  Instead of adding/subtracting `n`, use `n * obj.freq`

# %%
final_data['Travel_year_Month'] = pd.to_datetime(final_data['Date of Travel']).dt.to_period('M')
final_data['Year of Travel']=pd.DatetimeIndex(final_data['Date of Travel']).year
final_data['Month of Travel']=pd.DatetimeIndex(final_data['Date of Travel']).month
final_data
# Out:
#         Transaction ID Date of Travel     Company           City  \
# 0             10000011     2016-01-07    Pink Cab     ATLANTA GA
# 1             10351127     2018-07-20  Yellow Cab     ATLANTA GA
# 2             10412921     2018-11-22  Yellow Cab     ATLANTA GA
# 3             10000012     2016-01-05    Pink Cab     ATLANTA GA
# 4             10320494     2018-04-20  Yellow Cab     ATLANTA GA
# ...                ...            ...         ...            ...
# 359387        10307228     2018-03-02  Yellow Cab  WASHINGTON DC
# 359388        10319775     2018-04-12  Yellow Cab  WASHINGTON DC
# 359389        10347676     2018-07-05  Yellow Cab  WASHINGTON DC
# 359390        10358624     2018-08-01  Yellow Cab  WASHINGTON DC
# 359391        10370709     2018-08-29  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode  \
# 0              30.45         370.95      313.6350        29290         Card
# 1              26.19         598.70      317.4228        29290         Cash
# 2              42.55         792.05      597.4020        29290         Card
# 3              28.62         358.52      334.8540        27703         Card
# 4              36.38         721.10      467.1192        27703         Card
# ...              ...            ...           ...          ...          ...
# 359387         38.40         668.93      525.3120        51406         Cash
# 359388          3.57          67.60       44.5536        51406         Cash
# 359389         23.46         331.97      337.8240        51406         Card
# 359390         27.60         358.23      364.3200        51406         Cash
# 359391         34.24         453.11      427.3152        51406         Card
#
#         Gender  Age  Income (USD/Month)  Population     Users    Profit  \
# 0         Male   28             10813.0    814885.0   24701.0   57.3150
# 1         Male   28             10813.0    814885.0   24701.0  281.2772
# 2         Male   28             10813.0    814885.0   24701.0  194.6480
# 3         Male   27              9237.0    814885.0   24701.0   23.6660
# 4         Male   27              9237.0    814885.0   24701.0  253.9808
# ...        ...  ...                 ...         ...       ...       ...
# 359387  Female   29              6829.0    418859.0  127001.0  143.6180
# 359388  Female   29              6829.0    418859.0  127001.0   23.0464
# 359389  Female   29              6829.0    418859.0  127001.0   -5.8540
# 359390  Female   29              6829.0    418859.0  127001.0   -6.0900
# 359391  Female   29              6829.0    418859.0  127001.0   25.7948
#
#        Travel_year_Month  Year of Travel  Month of Travel
# 0                2016-01            2016                1
# 1                2018-07            2018                7
# 2                2018-11            2018               11
# 3                2016-01            2016                1
# 4                2018-04            2018                4
# ...                  ...             ...              ...
# 359387           2018-03            2018                3
# 359388           2018-04            2018                4
# 359389           2018-07            2018                7
# 359390           2018-08            2018                8
# 359391           2018-08            2018                8
#
# [359392 rows x 18 columns]

# %% [markdown]
# #### Date of travel is in the right data type

# %% [markdown]
# ### Separating Yellow Cab data and Pink Cab data.

# %% [markdown]
# #### Yellow Cab data first

# %%
yellow_cab = final_data[final_data.Company.isin(["Yellow Cab"])]
yellow_cab.head()
# Out:
#    Transaction ID Date of Travel     Company        City  KM Travelled  \
# 1        10351127     2018-07-20  Yellow Cab  ATLANTA GA         26.19
# 2        10412921     2018-11-22  Yellow Cab  ATLANTA GA         42.55
# 4        10320494     2018-04-20  Yellow Cab  ATLANTA GA         36.38
# 5        10324737     2018-05-03  Yellow Cab  ATLANTA GA          6.18
# 8        10079404     2016-09-20  Yellow Cab  ATLANTA GA         39.60
#
#    Price Charged  Cost of Trip  Customer ID Payment_Mode Gender  Age  \
# 1         598.70      317.4228        29290         Cash   Male   28
# 2         792.05      597.4020        29290         Card   Male   28
# 4         721.10      467.1192        27703         Card   Male   27
# 5         138.40       87.5088        27703         Cash   Male   27
# 8         704.30      494.2080        28712         Card   Male   53
#
#    Income (USD/Month)  Population    Users    Profit Travel_year_Month  \
# 1             10813.0    814885.0  24701.0  281.2772           2018-07
# 2             10813.0    814885.0  24701.0  194.6480           2018-11
# 4              9237.0    814885.0  24701.0  253.9808           2018-04
# 5              9237.0    814885.0  24701.0   50.8912           2018-05
# 8             11242.0    814885.0  24701.0  210.0920           2016-09
#
#    Year of Travel  Month of Travel
# 1            2018                7
# 2            2018               11
# 4            2018                4
# 5            2018                5
# 8            2016                9

# %% [markdown]
# #### Pink Cab data

# %%
pink_cab = final_data[final_data.Company.isin(["Pink Cab"])]
pink_cab.head()
# Out:
#     Transaction ID Date of Travel   Company        City  KM Travelled  \
# 0         10000011     2016-01-07  Pink Cab  ATLANTA GA         30.45
# 3         10000012     2016-01-05  Pink Cab  ATLANTA GA         28.62
# 6         10395626     2018-10-26  Pink Cab  ATLANTA GA         13.39
# 7         10000013     2016-01-01  Pink Cab  ATLANTA GA          9.04
# 11        10000014     2016-01-06  Pink Cab  ATLANTA GA         33.17
#
#     Price Charged  Cost of Trip  Customer ID Payment_Mode Gender  Age  \
# 0          370.95       313.635        29290         Card   Male   28
# 3          358.52       334.854        27703         Card   Male   27
# 6          167.03       141.934        27703         Card   Male   27
# 7          125.20        97.632        28712         Cash   Male   53
# 11         377.40       351.602        28020         Cash   Male   23
#
#     Income (USD/Month)  Population    Users  Profit Travel_year_Month  \
# 0              10813.0    814885.0  24701.0  57.315           2016-01
# 3               9237.0    814885.0  24701.0  23.666           2016-01
# 6               9237.0    814885.0  24701.0  25.096           2018-10
# 7              11242.0    814885.0  24701.0  27.568           2016-01
# 11             23327.0    814885.0  24701.0  25.798           2016-01
#
#     Year of Travel  Month of Travel
# 0             2016                1
# 3             2016                1
# 6             2018               10
# 7             2016                1
# 11            2016                1

# %% [markdown]
# ### Plot 8: Pink Cab users vs Yellow Cab users

# %%
plt.figure(figsize=(10,5))
sns.countplot(final_data.Company, palette = "twilight")
plt.title(" Pink vs Yellow Cab Users ", size = 15)
plt.xlabel("Company")
plt.ylabel("Users")
plt.show()
# Out:
# C:\Users\aaroh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Plot 8: Pink vs Yellow Cab Profit

# %%
plt.title(" PROFIT PER COMPANY ")
profits = final_data.groupby('Company')['Profit'].sum()
colour = ['#4F6272', '#B7C3F3']
profits.plot(kind='pie',y='Company',startangle=20,figsize=(17,9),autopct='%1.1f%%',explode=[0.03]*2, colors = colour)
# Out:
# <AxesSubplot:title={'center':' PROFIT PER COMPANY '}, ylabel='Profit'>

# %% [markdown]
# #### We can see Yellow Cab makes 89.2% of total profits

# %%
yellow_cab.dtypes
# Out:
# Transaction ID                 int64
# Date of Travel        datetime64[ns]
# Company                       object
# City                          object
# KM Travelled                 float64
# Price Charged                float64
# Cost of Trip                 float64
# Customer ID                    int64
# Payment_Mode                  object
# Gender                        object
# Age                            int64
# Income (USD/Month)           float64
# Population                   float64
# Users                        float64
# Profit                       float64
# Travel_year_Month          period[M]
# Year of Travel                 int64
# Month of Travel                int64
# dtype: object

# %% [markdown]
# #### Date of travel is in the right data type

# %%
# renaming columns

final_data.rename(columns = {'Transaction ID':'Transaction_ID'}, inplace = True)
pink_cab.rename(columns = {'Transaction ID':'Transaction_ID'}, inplace = True)
yellow_cab.rename(columns = {'Transaction ID':'Transaction_ID'}, inplace = True)

final_data.rename(columns = {'KM Travelled':'KM_Travelled'}, inplace = True)
pink_cab.rename(columns = {'KM Travelled':'KM_Travelled'}, inplace = True)
yellow_cab.rename(columns = {'KM Travelled':'KM_Travelled'}, inplace = True)

final_data.rename(columns = {'Cost of Trip':'Cost_of_Trip'}, inplace = True)
pink_cab.rename(columns = {'Cost of Trip':'Cost_of_Trip'}, inplace = True)
yellow_cab.rename(columns = {'Cost of Trip':'Cost_of_Trip'}, inplace = True)

yellow_cab.head(1)
# Out:
# C:\Users\aaroh\anaconda3\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#    Transaction_ID Date of Travel     Company        City  KM_Travelled  \
# 1        10351127     2018-07-20  Yellow Cab  ATLANTA GA         26.19
#
#    Price Charged  Cost_of_Trip  Customer ID Payment_Mode Gender  Age  \
# 1          598.7      317.4228        29290         Cash   Male   28
#
#    Income (USD/Month)  Population    Users    Profit Travel_year_Month  \
# 1             10813.0    814885.0  24701.0  281.2772           2018-07
#
#    Year of Travel  Month of Travel
# 1            2018                7

# %%
final_data.head(1)
# Out:
#    Transaction_ID Date of Travel   Company        City  KM_Travelled  \
# 0        10000011     2016-01-07  Pink Cab  ATLANTA GA         30.45
#
#    Price Charged  Cost_of_Trip  Customer ID Payment_Mode Gender  Age  \
# 0         370.95       313.635        29290         Card   Male   28
#
#    Income (USD/Month)  Population    Users  Profit Travel_year_Month  \
# 0             10813.0    814885.0  24701.0  57.315           2016-01
#
#    Year of Travel  Month of Travel
# 0            2016                1

# %%
pink_cab.head(1)
# Out:
#    Transaction_ID Date of Travel   Company        City  KM_Travelled  \
# 0        10000011     2016-01-07  Pink Cab  ATLANTA GA         30.45
#
#    Price Charged  Cost_of_Trip  Customer ID Payment_Mode Gender  Age  \
# 0         370.95       313.635        29290         Card   Male   28
#
#    Income (USD/Month)  Population    Users  Profit Travel_year_Month  \
# 0             10813.0    814885.0  24701.0  57.315           2016-01
#
#    Year of Travel  Month of Travel
# 0            2016                1

# %% [markdown]
# ### Plot 9: Number of Transactions (Yearly) per Company

# %%
pl1 = pink_cab.groupby("Year of Travel").Transaction_ID.count()
pl2 = yellow_cab.groupby("Year of Travel").Transaction_ID.count()


plt.figure(figsize=(17,9))
ax1 = plt.subplot(111)
ax1.bar(pl1.index-0.2, pl1.values, width=0.4, color='pink', align='center',label='Pink Cab')
ax1.bar(pl1.index+0.2, pl2.values, width=0.4, color='yellow', align='center',label='Yellow Cab')
plt.title("Pink cab vs Yellow cab",fontsize = 16)
plt.ylabel('No. of Transactions',fontsize = 14)
plt.xlabel('Year',fontsize = 14)
plt.legend()
plt.show()

# %% [markdown]
# #### On a yearly basis, Yellow Cab has significantly more # of transactions than Pink Cab

# %% [markdown]
# ### Plot 10: Pink Cab KM Travelled

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=pink_cab, x='KM_Travelled', y='Cost_of_Trip')
plt.title('Pink Cab KM Travelled',fontsize = 20)
plt.ylabel('Pink Cab Cost of trip',fontsize = 16)
plt.xlabel('Pink Cab KM Travelled',fontsize = 16)
plt.show()

# %% [markdown]
# ### Plot 11: Yellow Cab KM Travelled

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=yellow_cab, x='KM_Travelled', y='Cost_of_Trip', palette ="pink")
plt.title('Yellow Cab KM Travelled',fontsize = 20)
plt.ylabel('Yellow Cab Cost of trip',fontsize = 16)
plt.xlabel('Yellow Cab KM Travelled',fontsize = 16)
plt.show()

# %% [markdown]
# #### Cost of trips for both yellow cab and pink cab are relatively the same.

# %%
final_data.head()
# Out:
#    Transaction_ID Date of Travel     Company        City  KM_Travelled  \
# 0        10000011     2016-01-07    Pink Cab  ATLANTA GA         30.45
# 1        10351127     2018-07-20  Yellow Cab  ATLANTA GA         26.19
# 2        10412921     2018-11-22  Yellow Cab  ATLANTA GA         42.55
# 3        10000012     2016-01-05    Pink Cab  ATLANTA GA         28.62
# 4        10320494     2018-04-20  Yellow Cab  ATLANTA GA         36.38
#
#    Price Charged  Cost_of_Trip  Customer ID Payment_Mode Gender  Age  \
# 0         370.95      313.6350        29290         Card   Male   28
# 1         598.70      317.4228        29290         Cash   Male   28
# 2         792.05      597.4020        29290         Card   Male   28
# 3         358.52      334.8540        27703         Card   Male   27
# 4         721.10      467.1192        27703         Card   Male   27
#
#    Income (USD/Month)  Population    Users    Profit Travel_year_Month  \
# 0             10813.0    814885.0  24701.0   57.3150           2016-01
# 1             10813.0    814885.0  24701.0  281.2772           2018-07
# 2             10813.0    814885.0  24701.0  194.6480           2018-11
# 3              9237.0    814885.0  24701.0   23.6660           2016-01
# 4              9237.0    814885.0  24701.0  253.9808           2018-04
#
#    Year of Travel  Month of Travel
# 0            2016                1
# 1            2018                7
# 2            2018               11
# 3            2016                1
# 4            2018                4

# %% [markdown]
# ### Analyzing Profit

# %% [markdown]
# ### Plot 12: Profit per Month (Pink vs Yellow Cab)

# %%
plt.figure(figsize=(20,14))
po= sns.barplot(final_data['Month of Travel'], final_data["Profit"], hue="Company", data=final_data)
plt.title("Profit Per Month")
plt.show()
# Out:
# C:\Users\aaroh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #### Yelllow Cab makes more profit monthly

# %% [markdown]
# ### Plot 13: Profit Per Year

# %%
pivot_year_profit = final_data.pivot_table(index = ['Year of Travel'], columns = 'Company', values = 'Profit', aggfunc = 'sum')
pivot_year_profit
# Out:
# Company            Pink Cab    Yellow Cab
# Year of Travel
# 2016            1739882.628  1.407389e+07
# 2017            2015100.657  1.646427e+07
# 2018            1552345.036  1.348222e+07

# %%
plt.figure(figsize=(33,18))
p11=sns.barplot(data=final_data, x=final_data["Year of Travel"], y=final_data["Profit"], hue='Company')
plt.title('Profit Per Year',fontsize = 20)
plt.ylabel("Profit",fontsize = 16)
plt.xlabel("Year",fontsize = 16)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(20,10))
sns.barplot(final_data['City'],final_data['Price Charged'], hue='Company',data=final_data)
xt = plt.xticks(rotation=70)
plt.title("Profit Per City")
plt.show
# Out:
# C:\Users\aaroh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Yellow Cab charges more overall in comparison to Pink Cab in every city. Pink Cab have consistent profit across all cities.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Most customers travel with Yellow Cab
# - Yellow Cab is more perferable to customers
# - Yellow Cab charges more in populated cities incomparison to Pink Cab
# - Yellow Cab owns 89% of the profit; Pink Cab 10.8%
# - Pink Cab has consistent profits
# - Yellow Cab strategically charges more for their services in highly-populated cities
#
# I would advise XYZ company to invest in Yellow Cab for their consistent high performance.
